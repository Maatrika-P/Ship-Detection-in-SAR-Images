# %% [markdown]
# # Training the YOLOv8 model on HRSID

# %%
from ultralytics import YOLO

# %%
model =YOLO('yolov8n.pt')

# %% [markdown]
# ## Parameters
#
# - Training Epochs: `epochs=100`
# - Input Image Size: `imgsz=800`
# - Save Checkpoints: `save=True`
# - Early Stopping Patience: `patience=10`
# - Optimizer: `optimizer='Adam'`
# - Initial Learning Rate: `lr0=0.001`
# - Batch Size: `batch=8`

# %%
results = model.train(data='./config.yaml',epochs=100, imgsz=800, save=True, patience = 10, optimizer = 'Adam', lr0 = 0.001, batch = 8)
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.13 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %% [markdown]
# # Sample Predictions

# %% [markdown]
# These are on validation data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These are on train data

# %% [markdown]
# ![image.png](attachment:image.png)
